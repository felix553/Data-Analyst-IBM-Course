# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# %pip install wget
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting wget
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9681 sha256=b0925efd469f358f0f78de200c6b874eb16cca9958226c967747c2d02db9c0de
#   Stored in directory: c:\users\micha\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
# DEPRECATION: torchsde 0.2.5 has a non-standard dependency specifier numpy>=1.19.*; python_version >= "3.7". pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of torchsde or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# ...

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2023-08-03 18:51:09--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: 'm4_survey_data.sqlite'
#
#      0K .......... .......... .......... .......... ..........  0%  116K 5m8s
#     50K .......... .......... .......... .......... ..........  0% 1.71M 2m44s
#    100K .......... .......... .......... .......... ..........  0%  263K 2m34s
#    150K .......... .......... .......... .......... ..........  0% 2.12M 2m0s
# ...

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
#                                                   sql
# 0   CREATE TABLE "EduOther" (\n"Respondent" INTEGE...
# 1   CREATE TABLE "DevType" (\n"Respondent" INTEGER...
# 2   CREATE TABLE "LastInt" (\n"Respondent" INTEGER...
# 3   CREATE TABLE "JobFactors" (\n"Respondent" INTE...
# 4   CREATE TABLE "WorkPlan" (\n"Respondent" INTEGE...
# 5   CREATE TABLE "WorkChallenge" (\n"Respondent" I...
# 6   CREATE TABLE "LanguageWorkedWith" (\n"Responde...
# 7   CREATE TABLE "LanguageDesireNextYear" (\n"Resp...
# 8   CREATE TABLE "DatabaseWorkedWith" (\n"Responde...
# 9   CREATE TABLE "DatabaseDesireNextYear" (\n"Resp...
# 10  CREATE TABLE "PlatformWorkedWith" (\n"Responde...
# 11  CREATE TABLE "PlatformDesireNextYear" (\n"Resp...
# 12  CREATE TABLE "WebFrameWorkedWith" (\n"Responde...
# 13  CREATE TABLE "WebFrameDesireNextYear" (\n"Resp...
# 14  CREATE TABLE "MiscTechWorkedWith" (\n"Responde...
# 15  CREATE TABLE "MiscTechDesireNextYear" (\n"Resp...
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here

table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT ConvertedComp FROM master
"""

df = pd.read_sql_query(QUERY,conn)
df.plot(kind='hist', bins=10, xlabel='Compensation', title='Histogram of Converted Compensation')
# Out:
# <Axes: title={'center': 'Histogram of Converted Compensation'}, xlabel='Compensation', ylabel='Frequency'>

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here

QUERY = """
SELECT Age FROM master
"""

df = pd.read_sql_query(QUERY, conn)
df.plot(kind='box', title='Boxplot of Age of Respondents')
# Out:
# <Axes: title={'center': 'Boxplot of Age of Respondents'}>

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here

QUERY = """
SELECT Age, WorkWeekHrs FROM master
"""

df = pd.read_sql_query(QUERY, conn)
df.plot(kind='scatter', x='Age', y='WorkWeekHrs', xlabel='Age', ylabel='WorkWeekHrs', title='Age vs Work hours per week')
# Out:
# <Axes: title={'center': 'Age vs Work hours per week'}, xlabel='Age', ylabel='WorkWeekHrs'>

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# your code goes here

QUERY = """
SELECT Age, WorkWeekHrs, CodeRevHrs FROM master
"""

df = pd.read_sql_query(QUERY, conn)
ax = sns.scatterplot(data=df, x='WorkWeekHrs', y='CodeRevHrs', size='Age', legend=True)
plt.title('Work hrs vs Coding hrs per week in Comparison to Age')
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(*) AS Count FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY Count DESC
LIMIT 5

"""

df = pd.read_sql_query(QUERY, conn)
plt.pie(df['Count'], labels=df['DatabaseDesireNextYear'], autopct='%1.1f%%')
plt.show()
print(df)
# Out:
#   DatabaseDesireNextYear  Count
# 0             PostgreSQL   4328
# 1                MongoDB   3649
# 2                  Redis   3331
# 3                  MySQL   3281
# 4          Elasticsearch   2856

# %%
QUERY = """
SELECT LanguageDesireNextYear, COUNT(*) AS Count FROM LanguageDesireNextYear
GROUP BY LanguageDesireNextYear
ORDER BY Count DESC

"""

df = pd.read_sql_query(QUERY, conn)
plt.pie(df['Count'], labels=df['LanguageDesireNextYear'], autopct='%1.1f%%')
plt.show()
print(df)
# Out:
#    LanguageDesireNextYear  Count
# 0              JavaScript   6630
# 1                HTML/CSS   5328
# 2                  Python   5239
# 3                     SQL   5012
# 4              TypeScript   4088
# 5                      C#   3591
# 6   Bash/Shell/PowerShell   3097
# 7                    Java   2953
# 8                      Go   2759
# 9                  Kotlin   1890
# 10                    C++   1633
# 11                   Rust   1520
# 12                    PHP   1457
# 13            WebAssembly   1397
# 14                  Swift   1179
# 15                   Ruby   1029
# 16                      C   1028
# 17                  Scala    879
# 18                      R    850
# 19              Other(s):    836
# 20                     F#    621
# 21                 Elixir    620
# 22                   Dart    610
# 23                Clojure    413
# 24               Assembly    336
# 25            Objective-C    310
# 26                 Erlang    310
# ...

# %%
QUERY = """
SELECT DevType, COUNT(*) AS Count FROM DevType
GROUP BY DevType
ORDER BY Count DESC

"""

df = pd.read_sql_query(QUERY, conn)

print(df)
# Out:
#                                           DevType  Count
# 0                           Developer, full-stack   6928
# 1                             Developer, back-end   6290
# 2                            Developer, front-end   3920
# 3   Developer, desktop or enterprise applications   2575
# 4                               Developer, mobile   1959
# 5                               DevOps specialist   1639
# 6                          Database administrator   1413
# 7                            System administrator   1202
# 8                                        Designer    988
# 9                           Developer, QA or test    911
# 10    Developer, embedded applications or devices    854
# 11                                 Engineer, data    832
# 12  Data scientist or machine learning specialist    803
# 13                       Data or business analyst    802
# 14                                        Student    766
# ...

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here


QUERY = """
SELECT Age, MEDIAN(WorkWeekHrs), MEDIAN(CodeRevHrs) FROM master
WHERE Age <= 35 AND Age >= 30
GROUP BY Age
ORDER BY Age
"""

df = pd.read_sql_query(QUERY, conn)
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\micha\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:2200, in SQLiteDatabase.execute(self, sql, params)
#    2199 try:
# -> 2200     cur.execute(sql, *args)
#    2201     return cur
#
# OperationalError: no such function: MEDIAN
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[30], line 11
#       1 # your code goes here
#       4 QUERY = """
#       5 SELECT Age, MEDIAN(WorkWeekHrs), MEDIAN(CodeRevHrs) FROM master
#       6 WHERE Age <= 35 AND Age >= 30
#       7 GROUP BY Age
#       8 ORDER BY Age
#       9 """
# ---> 11 df = pd.read_sql_query(QUERY, conn)
#      12 df.head()
#
# ...

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
